# %% [markdown]
# # Drug Usage Predictor - Experimentation Notebook
#
# Linear Regression with Gradient Descent

# %%
# Import libraries

# %%
# Generate synthetic data

# %%
# Train model

# %%
# Evaluate and visualize
